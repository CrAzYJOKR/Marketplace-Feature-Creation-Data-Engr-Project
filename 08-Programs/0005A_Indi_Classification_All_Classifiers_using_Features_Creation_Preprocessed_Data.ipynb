# %% [markdown]
# ###**Step 1: Import the required packages**

# %%
from sklearn.ensemble import AdaBoostClassifier
from sklearn.preprocessing import LabelEncoder
from sklearn.tree import DecisionTreeClassifier
import pandas as pd
import numpy as np
# Import train_test_split function
from sklearn.model_selection import train_test_split
#Import scikit-learn metrics module for accuracy calculation
from sklearn import metrics
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.metrics import accuracy_score
from sklearn.metrics import confusion_matrix
from sklearn.metrics import classification_report
from sklearn import svm
from sklearn.svm import SVC
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.naive_bayes import GaussianNB
from sklearn.naive_bayes import MultinomialNB
from sklearn.tree import DecisionTreeClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.model_selection import cross_val_score
from sklearn import preprocessing
# %matplotlib inline
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# ###**Step 2: Import the data set**

# %%
# Mount the Google Drive
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
# Read the Diabetes Data from .csv file and check the data shape (number of Rows and Columns)
df = pd.read_csv("gdrive/My Drive/SRM-Internship-2021-Latest/Marketplace-Features-Creation-Project/06-Output-cum-Input-Files4/Mkt_Features_Preprocessed.csv")
print(df.shape)
df.head()
# Out:
# (23835, 32)
#    No_of_days_Visited_7_Days  ...  Target_Customers
# 0                   0.364160  ...                 0
# 1                  -0.667425  ...                 0
# 2                   0.364160  ...                 0
# 3                  -0.667425  ...                 0
# 4                   3.458916  ...                 0
#
# [5 rows x 32 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23835 entries, 0 to 23834
# Data columns (total 32 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   No_of_days_Visited_7_Days       23835 non-null  float64
#  1   No_Of_Products_Viewed_15_Days   23835 non-null  float64
#  2   User_Vintage                    23835 non-null  float64
#  3   Pageloads_last_7_days           23835 non-null  float64
#  4   Clicks_last_7_days              23835 non-null  float64
#  5   Most_Viewed_product_15_Days_0   23835 non-null  float64
#  6   Most_Viewed_product_15_Days_1   23835 non-null  float64
#  7   Most_Viewed_product_15_Days_2   23835 non-null  float64
#  8   Most_Viewed_product_15_Days_3   23835 non-null  float64
#  9   Most_Viewed_product_15_Days_4   23835 non-null  float64
#  10  Most_Viewed_product_15_Days_5   23835 non-null  float64
#  11  Most_Viewed_product_15_Days_6   23835 non-null  float64
#  12  Most_Viewed_product_15_Days_7   23835 non-null  float64
#  13  Most_Viewed_product_15_Days_8   23835 non-null  float64
#  14  Most_Viewed_product_15_Days_9   23835 non-null  float64
#  15  Most_Viewed_product_15_Days_10  23835 non-null  float64
#  16  Most_Active_OS_0                23835 non-null  float64
#  17  Most_Active_OS_1                23835 non-null  float64
#  18  Most_Active_OS_2                23835 non-null  float64
#  19  Most_Active_OS_3                23835 non-null  float64
#  20  Recently_Viewed_Product_0       23835 non-null  float64
#  21  Recently_Viewed_Product_1       23835 non-null  float64
#  22  Recently_Viewed_Product_2       23835 non-null  float64
#  23  Recently_Viewed_Product_3       23835 non-null  float64
#  24  Recently_Viewed_Product_4       23835 non-null  float64
#  25  Recently_Viewed_Product_5       23835 non-null  float64
#  26  Recently_Viewed_Product_6       23835 non-null  float64
#  27  Recently_Viewed_Product_7       23835 non-null  float64
#  28  Recently_Viewed_Product_8       23835 non-null  float64
#  29  Recently_Viewed_Product_9       23835 non-null  float64
#  30  Recently_Viewed_Product_10      23835 non-null  float64
#  31  Target_Customers                23835 non-null  int64
# dtypes: float64(31), int64(1)
# memory usage: 5.8 MB

# %%
df.isnull().sum()
# Out:
# No_of_days_Visited_7_Days         0
# No_Of_Products_Viewed_15_Days     0
# User_Vintage                      0
# Pageloads_last_7_days             0
# Clicks_last_7_days                0
# Most_Viewed_product_15_Days_0     0
# Most_Viewed_product_15_Days_1     0
# Most_Viewed_product_15_Days_2     0
# Most_Viewed_product_15_Days_3     0
# Most_Viewed_product_15_Days_4     0
# Most_Viewed_product_15_Days_5     0
# Most_Viewed_product_15_Days_6     0
# Most_Viewed_product_15_Days_7     0
# Most_Viewed_product_15_Days_8     0
# Most_Viewed_product_15_Days_9     0
# Most_Viewed_product_15_Days_10    0
# Most_Active_OS_0                  0
# Most_Active_OS_1                  0
# Most_Active_OS_2                  0
# Most_Active_OS_3                  0
# Recently_Viewed_Product_0         0
# Recently_Viewed_Product_1         0
# Recently_Viewed_Product_2         0
# Recently_Viewed_Product_3         0
# Recently_Viewed_Product_4         0
# Recently_Viewed_Product_5         0
# Recently_Viewed_Product_6         0
# Recently_Viewed_Product_7         0
# Recently_Viewed_Product_8         0
# Recently_Viewed_Product_9         0
# Recently_Viewed_Product_10        0
# Target_Customers                  0
# dtype: int64

# %% [markdown]
# ###**Step 4: Data Slicing**

# %%
X1 = df.drop(['Target_Customers'], axis = 1)
Y = df['Target_Customers']
X1.head()
# Out:
#    No_of_days_Visited_7_Days  ...  Recently_Viewed_Product_10
# 0                   0.364160  ...                    0.948982
# 1                  -0.667425  ...                   -1.053761
# 2                   0.364160  ...                    0.948982
# 3                  -0.667425  ...                   -1.053761
# 4                   3.458916  ...                    0.948982
#
# [5 rows x 31 columns]

# %%
Y.head()
# Out:
# 0    0
# 1    0
# 2    0
# 3    0
# 4    0
# Name: Target_Customers, dtype: int64

# %%
from sklearn.model_selection import train_test_split
X_train1, X_test1, Y_train, Y_test = train_test_split(X1, Y, test_size = 0.2, random_state = 66)

# %%
print(X_train1.shape)
print(Y_train.shape)
print(X_test1.shape)
print(Y_test.shape)
# Out:
# (19068, 31)
# (19068,)
# (4767, 31)
# (4767,)

# %% [markdown]
# ###**Step 5: Using all the Classifiers including Boosting Classifiers**

# %% [markdown]
# ##**Hold-Out Method**

# %% [markdown]
# ###**1) LogisticRegression**

# %%
from sklearn.linear_model import LogisticRegression
lr_clf = LogisticRegression(random_state = 0)
lr_clf.fit(X_train1, Y_train)
# Out:
# LogisticRegression(random_state=0)

# %%
lr_clf_Train_acc= lr_clf.score(X_train1,Y_train)
lr_clf_Test_acc= lr_clf.score(X_test1,Y_test)

# %%
print('Accuracy on training set:',lr_clf_Train_acc)
print('Accuracy on test set:',lr_clf_Test_acc)
# Out:
# Accuracy on training set: 0.9942836165303126
# Accuracy on test set: 0.9930774071743235

# %% [markdown]
# ###**2) Naive Bayes Classifier**

# %%
from sklearn.naive_bayes import GaussianNB
nb_clf= GaussianNB()
nb_clf.fit(X_train1, Y_train)
# Out:
# GaussianNB()

# %%
nb_clf_Train_acc=nb_clf.score(X_train1,Y_train)
nb_clf_Test_acc=nb_clf.score(X_test1,Y_test)

# %%
print('Accuracy on training set:',nb_clf_Train_acc)
print('Accuracy on test set:',nb_clf_Test_acc)
# Out:
# Accuracy on training set: 0.9138871407593875
# Accuracy on test set: 0.9135724774491294

# %% [markdown]
# ###**3) RandomForest Classifier**

# %%
from sklearn.ensemble import RandomForestRegressor
rf_clf = RandomForestRegressor(n_estimators = 10, random_state = 0)
rf_clf.fit(X_train1, Y_train)
# Out:
# RandomForestRegressor(n_estimators=10, random_state=0)

# %%
rf_clf_Train_acc = rf_clf.score(X_train1,Y_train)
rf_clf_Test_acc=rf_clf.score(X_test1,Y_test)

# %%
print('Accuracy on training set:',rf_clf_Train_acc)
print('Accuracy on test set:',rf_clf_Test_acc)
# Out:
# Accuracy on training set: 0.997980405655881
# Accuracy on test set: 0.9983163805891079

# %% [markdown]
# ###**4) DecisionTree Classifier**

# %%
from sklearn.tree import DecisionTreeClassifier
dec_clf = DecisionTreeClassifier()
dec_clf.fit(X_train1, Y_train)
# Out:
# DecisionTreeClassifier()

# %%
dec_clf_Train_acc=dec_clf.score(X_train1, Y_train)
dec_clf_Test_acc=dec_clf.score(X_test1, Y_test)

# %%
print('Accuracy on training set:', dec_clf_Train_acc)
print('Accuracy on test set:',dec_clf_Test_acc)
# Out:
# Accuracy on training set: 1.0
# Accuracy on test set: 1.0

# %% [markdown]
# ###**5) k-NN Classifier**

# %%
#You can change these hypfrom sklearn.neighbors import KNeighborsClassifiererparameters like metric etc.
knn_clf = KNeighborsClassifier(n_neighbors = 5, metric = 'minkowski', p = 2)  
knn_clf.fit(X_train1, Y_train)
# Out:
# KNeighborsClassifier()

# %%
kNN_Train_acc=knn_clf.score(X_train1,Y_train)
kNN_Test_acc=knn_clf.score(X_test1,Y_test)

# %%
print('Accuracy on training set:',kNN_Train_acc)
print('Accuracy on test set:',kNN_Test_acc)
# Out:
# Accuracy on training set: 0.9951751625760437
# Accuracy on test set: 0.9930774071743235

# %% [markdown]
# ###**6) Support Vector Classifier**

# %%
from sklearn.svm import SVC
svc_clf = SVC(kernel = 'rbf', random_state = 0)
svc_clf.fit(X_train1, Y_train)
# Out:
# SVC(random_state=0)

# %%
svc_Train_acc=svc_clf.score(X_train1,Y_train)
svc_Test_acc=svc_clf.score(X_test1,Y_test)

# %%
print('Accuracy on training set:',svc_Train_acc)
print('Accuracy on test set:', svc_Test_acc)
# Out:
# Accuracy on training set: 0.9987413467589679
# Accuracy on test set: 0.9937067337948395

# %% [markdown]
# ###**1) For SVC, Random Forest, LogisticRegression, Naive Bayes Classifier and Decision Tree Classifier**

# %%
model_params = {
     'svc': {
        'model': svm.SVC(gamma='auto'),
        'params' : {
            'C': [1,10,20],
            'kernel': ['rbf','linear']
        }  
    },
    'random_forest': {
        'model': RandomForestClassifier(),
        'params' : {
            'n_estimators': [1,5,10,100,200]
        }
    },
    'logistic_regression' : {
        'model': LogisticRegression(solver='liblinear',multi_class='auto'),
        'params': {
            'C': [1,5,10]
        }
    },
    'naive_bayes_gaussian': {
        'model': GaussianNB(),
        'params': {}
    },
    'decision_tree': {
        'model': DecisionTreeClassifier(),
        'params': {
            'criterion': ['gini','entropy'],
            
        }
    }     
}

# %%
from sklearn.model_selection import GridSearchCV
import pandas as pd
scores = []

for model_name, mp in model_params.items():
    clf =  GridSearchCV(mp['model'], mp['params'], cv=5, return_train_score=False)
    clf.fit(X1, Y)
    scores.append({
        'model': model_name,
        'best_score': clf.best_score_,
        'best_params': clf.best_params_
    })
    
df = pd.DataFrame(scores,columns=['model','best_score','best_params'])
df
# Out:
#                   model  best_score                 best_params
# 0                   svc    0.994881  {'C': 10, 'kernel': 'rbf'}
# 1         random_forest    0.998741       {'n_estimators': 100}
# 2   logistic_regression    0.993665                    {'C': 5}
# 3  naive_bayes_gaussian    0.910887                          {}
# 4         decision_tree    1.000000    {'criterion': 'entropy'}

# %% [markdown]
# ###**a) Using Logistic Regression**

# %%
# Logistic Regression
lr_grid_acc = cross_val_score(LogisticRegression(C=5, solver='liblinear',multi_class='auto'),X1, Y, cv=5)
print("lr_grid_acc (CV_based) :", lr_grid_acc)
lr_grid_acc_avg=np.average(lr_grid_acc)
print()
print("lr_grid_acc_avg : ", lr_grid_acc_avg)
# Out:
# lr_grid_acc (CV_based) : [0.99496539 0.99265786 0.99517516 0.99286763 0.99265786]
#
# lr_grid_acc_avg :  0.993664778686805

# %% [markdown]
# ###**b) Using SVC Classifier**

# %%
#SVC Classifier
svc_grid_acc = cross_val_score(SVC(C=10, kernel='linear', gamma = 'auto'),X1, Y, cv=5)
print("svc_grid_acc (CV_based) :", svc_grid_acc)
svc_grid_acc_avg=np.average(svc_grid_acc)
print()
print("svc_grid_acc_avg : ", svc_grid_acc_avg)
# Out:
# svc_grid_acc (CV_based) : [0.99433606 0.99328718 0.99538494 0.99202853 0.99265786]
#
# svc_grid_acc_avg :  0.993538913362702

# %% [markdown]
# ###**c) Using Naive Bayes Classifer**

# %%
#Naive Bayes Classifier
bayes_grid_acc = cross_val_score(GaussianNB(),X1, Y, cv=5)
print("bayes_grid_acc (CV_based) :", bayes_grid_acc)
bayes_grid_acc_avg=np.average(bayes_grid_acc)
print()
print("bayes_grid_acc_avg : ", bayes_grid_acc_avg)
# Out:
# bayes_grid_acc (CV_based) : [0.9219635  0.91105517 0.90539123 0.91210405 0.9039228 ]
#
# bayes_grid_acc_avg :  0.9108873505349276

# %% [markdown]
# ###**d) Using Decision Tree Classifier**

# %%
#Decision Tree Classifier
dtc_grid_acc = cross_val_score(DecisionTreeClassifier(criterion= 'entropy'), X1, Y, cv=5)
print("dtc_grid_acc (CV_based) :", dtc_grid_acc)
dtc_grid_acc_avg=np.average(dtc_grid_acc)
print()
print("dtc_grid_acc_avg : ", dtc_grid_acc_avg)
# Out:
# dtc_grid_acc (CV_based) : [1. 1. 1. 1. 1.]
#
# dtc_grid_acc_avg :  1.0

# %% [markdown]
# ###**e) Using Random Forest Classifier**

# %%
# Random Forest Classifier
rfc_grid_acc = cross_val_score(RandomForestClassifier(n_estimators=100), X1, Y, cv=5)
print("rfc_grid_acc (CV_based) :", rfc_grid_acc)
rfc_grid_acc_avg=np.average(rfc_grid_acc)
print()
print("rfc_grid_acc_avg : ", rfc_grid_acc_avg)
# Out:
# rfc_grid_acc (CV_based) : [1.         0.99895112 0.99937067 0.9983218  0.99790224]
#
# rfc_grid_acc_avg :  0.9989091671911057

# %% [markdown]
# ###**f) Using K-NN Classifier**

# %% [markdown]
# ###**Hyperparameters tuning and using GridSearchCV for KNN Classifier**

# %%
k_range = list(range(1,31))
weight_options = ["uniform", "distance"]

param_grid_knn = dict(n_neighbors = k_range, weights = weight_options)
#print (param_grid)
knn = KNeighborsClassifier()

grid_knn = GridSearchCV(knn, param_grid_knn, cv = 5, scoring = 'accuracy')

grid_knn.fit(X1, Y)

print (grid_knn.best_score_)
print (grid_knn.best_params_)
print (grid_knn.best_estimator_)
# Out:
# 0.9937067337948395
# {'n_neighbors': 14, 'weights': 'distance'}
# KNeighborsClassifier(n_neighbors=14, weights='distance')

# %%
# KNN Classifier
kNN_grid_acc = cross_val_score(KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
                     metric_params=None, n_jobs=None, n_neighbors=14, p=2,
                     weights='uniform'), X1, Y, cv =5)
print("kNN_grid_acc (CV_based) :", lr_grid_acc)
kNN_grid_acc_avg=np.average(kNN_grid_acc)
print()
print("kNN_grid_acc_avg : ", kNN_grid_acc_avg)
# Out:
# kNN_grid_acc (CV_based) : [0.99496539 0.99265786 0.99517516 0.99286763 0.99265786]
#
# kNN_grid_acc_avg :  0.9933710929305644

# %% [markdown]
# ###**g) Using AdaBoostClassifer**

# %%
model = DecisionTreeClassifier(criterion='entropy', max_depth=1)
AdaBoost = AdaBoostClassifier(base_estimator=model, n_estimators=400, learning_rate=1)

# %%
#Fit the model with training data
boostmodel = AdaBoost.fit(X_train1, Y_train)

# %%
#Evaluate the accuracy of the model
y_pred = boostmodel.predict(X_test1)
AdaBoost_acc = metrics.accuracy_score(Y_test, y_pred)
#Calculating the accuracy in percentage
print('The accuracy is: ', AdaBoost_acc * 100, '%')
# Out:
# The accuracy is:  100.0 %

# %%
AdaBoost_Train_acc= boostmodel.score(X_train1,Y_train)
AdaBoost_Test_acc= boostmodel.score(X_test1,Y_test)
print('Accuracy on training set:',AdaBoost_Train_acc)
print('Accuracy on test set:',AdaBoost_Test_acc)
# Out:
# Accuracy on training set: 1.0
# Accuracy on test set: 1.0

# %% [markdown]
# ###**h) Using GradientBoostingClassifier**

# %%
lr_list = [0.05, 0.075, 0.1, 0.25, 0.5, 0.75, 1]

for learning_rate in lr_list:
    gb_clf = GradientBoostingClassifier(n_estimators=20, learning_rate=learning_rate, max_features=2, max_depth=2, random_state=0)
    gb_clf.fit(X_train1, Y_train)

    print("Learning rate: ", learning_rate)
    print("Accuracy score (training): {0:.3f}".format(gb_clf.score(X_train1, Y_train)))
    print("Accuracy score (validation): {0:.3f}".format(gb_clf.score(X_test1, Y_test)))
# Out:
# Learning rate:  0.05
# Accuracy score (training): 0.990
# Accuracy score (validation): 0.990
# Learning rate:  0.075
# Accuracy score (training): 0.990
# Accuracy score (validation): 0.990
# Learning rate:  0.1
# Accuracy score (training): 0.992
# Accuracy score (validation): 0.992
# Learning rate:  0.25
# Accuracy score (training): 0.997
# Accuracy score (validation): 0.995
# Learning rate:  0.5
# Accuracy score (training): 0.995
# Accuracy score (validation): 0.995
# Learning rate:  0.75
# Accuracy score (training): 0.795
# Accuracy score (validation): 0.800
# Learning rate:  1
# Accuracy score (training): 0.010
# Accuracy score (validation): 0.010

# %%
from array import array
gb_clf2 = GradientBoostingClassifier(n_estimators=20, learning_rate=0.75, max_features=2, max_depth=2, random_state=0)
gb_clf2.fit(X_train1, Y_train)
predictions = gb_clf2.predict(X_test1)
#GradientBoosting_acc=gb_clf2.score(Y_test, predictions)
GradientBoosting_acc = metrics.accuracy_score(Y_test, predictions)
print("GradientBoosting_acc =", GradientBoosting_acc)
# Out:
# GradientBoosting_acc = 0.8002936857562408

# %%
GradientBoost_Train_acc= gb_clf2.score(X_train1,Y_train)
GradientBoost_Test_acc= gb_clf2.score(X_test1,Y_test)
print('Accuracy on training set:',GradientBoost_Train_acc)
print('Accuracy on test set:',GradientBoost_Test_acc)
# Out:
# Accuracy on training set: 0.7953639605621985
# Accuracy on test set: 0.8002936857562408

# %% [markdown]
# ###**i) Using XGBoostClassifier**

# %%
from xgboost import XGBClassifier
xgb_clf = XGBClassifier()
xgb_clf.fit(X_train1, Y_train)
# Out:
# XGBClassifier()

# %%
XGBoost_acc = xgb_clf.score(X_test1, Y_test)
print(XGBoost_acc)
# Out:
# 1.0

# %%
XGBoost_Train_acc= xgb_clf.score(X_train1,Y_train)
XGBoost_Test_acc= xgb_clf.score(X_test1,Y_test)
print('Accuracy on training set:',XGBoost_Train_acc)
print('Accuracy on test set:',XGBoost_Test_acc)
# Out:
# Accuracy on training set: 1.0
# Accuracy on test set: 1.0

# %% [markdown]
# ###**j) Using LightGBMClassifer**

# %%
import lightgbm as lgb
model_lgb = lgb.LGBMClassifier()
# fit the model with the training data
model_lgb.fit(X_train1,Y_train)
# Out:
# LGBMClassifier()

# %%
predict_train = model_lgb.predict(X_train1)
# Accuray Score on train dataset
accuracy_train = accuracy_score(Y_train,predict_train)
print('\naccuracy_score on train dataset : ', accuracy_train)
# Out:
# accuracy_score on train dataset :  1.0

# %%
# predict the target on the test dataset
predict_test = model_lgb.predict(X_test1)
# Accuracy Score on test dataset
LightGBM_acc = accuracy_score(Y_test,predict_test)
print('\naccuracy_score on test dataset : ', LightGBM_acc)
# Out:
# accuracy_score on test dataset :  1.0

# %%
LightGBM_Train_acc= model_lgb.score(X_train1,Y_train)
LightGBM_Test_acc= model_lgb.score(X_test1,Y_test)
print('Accuracy on training set:',LightGBM_Train_acc)
print('Accuracy on test set:',LightGBM_Test_acc)
# Out:
# Accuracy on training set: 1.0
# Accuracy on test set: 1.0

# %%
results={'Accuracy':[AdaBoost_acc, GradientBoosting_acc, XGBoost_acc, LightGBM_acc]}
columns=['ADABoostClassifer','GradientBoostClassifer','XGBoostClassifer', 'LightGBMClassifier']
aov_table=pd.DataFrame(results,columns)
aov_table
# Out:
#                         Accuracy
# ADABoostClassifer       1.000000
# GradientBoostClassifer  0.800294
# XGBoostClassifer        1.000000
# LightGBMClassifier      1.000000

# %% [markdown]
# ###**Finalizing a classification model based on performance**

# %%
df1 = pd.DataFrame({
    'ML Algorithm': ['Logistic_Regression','Naive_Bayes','Random_Forest', 'Decicion_Tree', 'k-NN', 'Support Vector Classifier', 'AdaBoostClassifier', 'GradientBoostingClassifier', 'XGBoostClassifier', 'LightGBMClassifier'],
    'Train_acc': [lr_clf_Train_acc, nb_clf_Train_acc, rf_clf_Train_acc, dec_clf_Train_acc, kNN_Train_acc, svc_Train_acc, AdaBoost_Train_acc, GradientBoost_Train_acc, XGBoost_Train_acc, LightGBM_Train_acc], 
    'Test_acc': [lr_clf_Test_acc, nb_clf_Test_acc, rf_clf_Test_acc, dec_clf_Test_acc, kNN_Test_acc, svc_Test_acc, AdaBoost_Test_acc, GradientBoost_Test_acc, XGBoost_Test_acc, LightGBM_Test_acc],
    'GridSearchCV_based_acc': [lr_grid_acc_avg, bayes_grid_acc_avg, rfc_grid_acc_avg, dtc_grid_acc_avg, kNN_grid_acc_avg, svc_grid_acc_avg,'N/A',  'N/A' , 'N/A', 'N/A'],
    'Suitability': ['Suitable', 'Not Suitable', 'Not Suitable', 'Not Suitable', 'Not Suitable', 'Not Suitable', 'Not Suitable', 'Suitable', 'Not Suitable', 'Not Suitable']})
df1
# Out:
#                  ML Algorithm  Train_acc  ...  GridSearchCV_based_acc   Suitability
# 0         Logistic_Regression   0.994284  ...                0.993665      Suitable
# 1                 Naive_Bayes   0.913887  ...                0.910887  Not Suitable
# 2               Random_Forest   0.997980  ...                0.998909  Not Suitable
# 3               Decicion_Tree   1.000000  ...                       1  Not Suitable
# 4                        k-NN   0.995175  ...                0.993371  Not Suitable
# 5   Support Vector Classifier   0.998741  ...                0.993539  Not Suitable
# 6          AdaBoostClassifier   1.000000  ...                     N/A  Not Suitable
# 7  GradientBoostingClassifier   0.795364  ...                     N/A      Suitable
# 8           XGBoostClassifier   1.000000  ...                     N/A  Not Suitable
# 9          LightGBMClassifier   1.000000  ...                     N/A  Not Suitable
#
# [10 rows x 5 columns]

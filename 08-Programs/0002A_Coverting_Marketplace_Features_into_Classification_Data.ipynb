# %%
import pandas as pd
import numpy as np
import warnings
warnings.filterwarnings("ignore")

# %%
# Mount the Google Drive
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
# Read the Visitors Data from .csv file and check the data shape (number of Rows and Columns)
Mkt_Features_Data = pd.read_csv('gdrive/My Drive/SRM-Internship-2021-Latest/Marketplace-Features-Creation-Project/03-Output-cum-Input-Files1/Marketplace_Features.csv')
print(Mkt_Features_Data.shape)
Mkt_Features_Data.head()
# Out:
# (34050, 9)
#     UserID  ...  Clicks_last_7_days
# 0  U106593  ...                   5
# 1  U108297  ...                   4
# 2  U132443  ...                   0
# 3  U134616  ...                   0
# 4  U130784  ...                   0
#
# [5 rows x 9 columns]

# %%
Mkt_Features_Data['Most_Viewed_product_15_Days'].value_counts()
# Out:
# Product101    9587
# PR100017      1858
# PR100102      1097
# PR100166       749
# PR100145       373
#               ...
# PR105100         1
# PR103294         1
# PR102142         1
# PR101266         1
# PR110389         1
# Name: Most_Viewed_product_15_Days, Length: 1781, dtype: int64

# %%
Mkt_Features_Data['Clicks_last_7_days'].value_counts()
# Out:
# 0      24850
# 1       2502
# 2       1445
# 3        934
# 4        686
#        ...
# 940        1
# 503        1
# 77         1
# 109        1
# 415        1
# Name: Clicks_last_7_days, Length: 188, dtype: int64

# %%
No_of_days_last7_days_mid_val = []
No_Of_Products_Viewed_15_Days_mid_val = []
User_Vintage_mid_val = []
Pageloads_last_7_days_mid_val = []
Clicks_last_7_days_mid_val = []

No_of_days_last7_days_mid1 =round(Mkt_Features_Data['No_of_days_Visited_7_Days'].max()/2)
No_of_days_last7_days_mid_val.append(No_of_days_last7_days_mid1)

No_Of_Products_Viewed_15_Days_mid1 =round(Mkt_Features_Data['No_Of_Products_Viewed_15_Days'].max()/2)
No_Of_Products_Viewed_15_Days_mid_val.append(No_Of_Products_Viewed_15_Days_mid1)

User_Vintage_mid1 =round(Mkt_Features_Data['User_Vintage'].max()/2)
User_Vintage_mid_val.append(User_Vintage_mid1)

Pageloads_last_7_days_mid1 =round(Mkt_Features_Data['Pageloads_last_7_days'].max()/2)
Pageloads_last_7_days_mid_val.append(Pageloads_last_7_days_mid1)

Clicks_last_7_days_mid1 =round(Mkt_Features_Data['Clicks_last_7_days'].max()/2)
Clicks_last_7_days_mid_val.append(Clicks_last_7_days_mid1)

final_df = pd.DataFrame()
final_df['No_of_days_Visited_7_Days'] = No_of_days_last7_days_mid_val
final_df['No_Of_Products_Viewed_15_Days'] = No_Of_Products_Viewed_15_Days_mid_val
final_df['User_Vintage'] = User_Vintage_mid_val
final_df['Pageloads_last_7_days'] = Pageloads_last_7_days_mid_val
final_df['Clicks_last_7_days'] = Clicks_last_7_days_mid_val

# %%
final_df.head()
# Out:
#    No_of_days_Visited_7_Days  ...  Clicks_last_7_days
# 0                          3  ...                2698
#
# [1 rows x 5 columns]

# %%
final_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1 entries, 0 to 0
# Data columns (total 5 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   No_of_days_Visited_7_Days      1 non-null      int64
#  1   No_Of_Products_Viewed_15_Days  1 non-null      int64
#  2   User_Vintage                   1 non-null      int64
#  3   Pageloads_last_7_days          1 non-null      int64
#  4   Clicks_last_7_days             1 non-null      int64
# dtypes: int64(5)
# memory usage: 168.0 bytes

# %%
Mkt_Features_Data1=Mkt_Features_Data.copy()

# %%
Mkt_Features_Data1.reset_index(drop=True, inplace=True)
Mkt_Features_Data1.head()
# Out:
#     UserID  ...  Clicks_last_7_days
# 0  U106593  ...                   5
# 1  U108297  ...                   4
# 2  U132443  ...                   0
# 3  U134616  ...                   0
# 4  U130784  ...                   0
#
# [5 rows x 9 columns]

# %%
target_customers = []
for i in range(Mkt_Features_Data1.shape[0]):
#    if final_df(['No_of_days_Visited_7_Days'][i] > 2698) & final_df(['No_Of_Products_Viewed_15_Days'][i] > 48) & final_df(['User_Vintage'][i] > 1367) & final_df(['Pageloads_last_7_days'][i] > 153) & final_df(['Clicks_last_7_days'][i] > 1367):
#     X=final_df['No_of_days_Visited_7_Days']
#     print(X)

     if (Mkt_Features_Data1['No_of_days_Visited_7_Days'][i] > 1) & (Mkt_Features_Data1['No_Of_Products_Viewed_15_Days'][i] > 2) & (Mkt_Features_Data1['User_Vintage'][i] > 21) & (Mkt_Features_Data1['Pageloads_last_7_days'][i] > 10) & (Mkt_Features_Data1['Clicks_last_7_days'][i] > 21) & (Mkt_Features_Data1['Most_Viewed_product_15_Days'][i] != 'Product101') & (Mkt_Features_Data1['Recently_Viewed_Product'][i] != 'Product101'):
#    if Mkt_Features_Data1['No_of_days_Visited_7_Days'][i] > 2 & Mkt_Features_Data1['No_Of_Products_Viewed_15_Days'][i] > 1:
        target_customers.append(1)
     else: 
        target_customers.append(0)

Mkt_Features_Data1['Target_Customers'] = target_customers

# %%
print(Mkt_Features_Data1.shape)
Mkt_Features_Data1.head()
# Out:
# (34050, 10)
#     UserID  No_of_days_Visited_7_Days  ...  Clicks_last_7_days  Target_Customers
# 0  U106593                          2  ...                   5                 0
# 1  U108297                          2  ...                   4                 0
# 2  U132443                          0  ...                   0                 0
# 3  U134616                          0  ...                   0                 0
# 4  U130784                          0  ...                   0                 0
#
# [5 rows x 10 columns]

# %%
Mkt_Features_Data1['Target_Customers'].value_counts()
# Out:
# 0    33725
# 1      325
# Name: Target_Customers, dtype: int64

# %%
from google.colab import files
Mkt_Features_Data1.to_csv("gdrive/My Drive/SRM-Internship-2021-Latest/Marketplace-Features-Creation-Project/04-Output-cum-Input-Files2/Mkt_Features_Classification.csv", index = False)
